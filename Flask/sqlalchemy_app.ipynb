# %%
import sqlalchemy
from sqlalchemy.ext.automap import automap_base
from sqlalchemy.orm import Session
from sqlalchemy import create_engine, func
import json

# %%
database_path = 'updated_earthquake.db'

# %%
engine = create_engine(f'sqlite:///{database_path}')

# %%
Base = automap_base()

# %%
Base.prepare(engine, reflect=True)

# %%
Base.classes.keys()
# Out:
# ['gdp',
#  'gdp_bra',
#  'gdp_chl',
#  'gdp_chn',
#  'gdp_gbr',
#  'gdp_idn',
#  'gdp_ind',
#  'gdp_jpn',
#  'gdp_rus',
#  'gdp_usa',
#  'quake']

# %%
quake = Base.classes.quake
gdp = Base.classes.gdp
gdp_bra = Base.classes.gdp_bra
gdp_chl = Base.classes.gdp_chl
gdp_chn = Base.classes.gdp_chn
gdp_gbr = Base.classes.gdp_gbr
gdp_idn = Base.classes.gdp_idn
gdp_ind = Base.classes.gdp_ind
gdp_jpn = Base.classes.gdp_jpn
gdp_rus = Base.classes.gdp_rus
gdp_usa = Base.classes.gdp_usa

# %%
session = Session(engine)

# %%
for row in session.query(quake.Place, quake.Longitude, quake.Latitude, quake.Magnitude).all():
    print(row)
# Out:
# ('2004 Sumatra - Andaman Islands Earthquake', 3.295, 95.982, 9.1)
# ('2011 Great Tohoku Earthquake, Japan', 38.297, 142.373, 9.1)
# ('offshore Bio-Bio, Chile', -36.122, -72.898, 8.8)
# ('northern Sumatra, Indonesia', 2.085, 97.108, 8.6)
# ('off the west coast of northern Sumatra', 2.327, 93.063, 8.6)
# ('southern Sumatra, Indonesia', -4.438, 101.367, 8.4)
# ('near the coast of southern Peru', -16.265, -73.641, 8.4)
# ('Sea of Okhotsk', 54.892, 153.221, 8.3)
# ('Kuril Islands', 46.592, 153.266, 8.3)
# ('48km W of Illapel, Chile', -31.5729, -71.6744, 8.3)
# ('101km SSW of Tres Picos, Mexico', 15.0222, -93.8993, 8.2)
# ('94km NW of Iquique, Chile', -19.6097, -70.7691, 8.2)
# ('off the west coast of northern Sumatra', 0.802, 92.463, 8.2)
# ('286km NNE of Ndoi Island, Fiji', -18.1125, -178.153, 8.2)
# ('Hokkaido, Japan region', 41.815, 143.91, 8.16)
# ('Samoa Islands region', -15.489, -172.095, 8.1)
# ('Solomon Islands', -8.466, 157.043, 8.1)
# ('east of the Kuril Islands', 46.243, 154.524, 8.1)
# ('Kermadec Islands, New Zealand', -29.7228, -177.2794, 8.1)
# ('north of Macquarie Island', -49.312, 161.345, 8.1)
# ('New Ireland region, Papua New Guinea', -3.98, 152.169, 8.0)
# ('Tonga', -20.187, -174.123, 8.0)
# ('78km SE of Lagunas, Peru', -5.8119, -75.2697, 8.0)
# ('near the coast of central Peru', -13.386, -76.603, 8.0)
# ('76km W of Lata, Solomon Islands', -10.799, 165.114, 8.0)
# ('Kepulauan Mentawai region, Indonesia', -2.625, 100.841, 7.9)
# ('280km SE of Kodiak, Alaska', 56.0039, -149.1658, 7.9)
# ('35km WNW of Panguna, Papua New Guinea', -6.2464, 155.1718, 7.9)
# ('54km E of Taron, Papua New Guinea', -4.5049, 153.5216, 7.9)
# ('102km ESE of Suva, Fiji', -18.4743, 179.3502, 7.9)
# ('southern Sumatra, Indonesia', -4.721, 102.087, 7.9)
# ('near the east coast of Honshu, Japan', 36.281, 141.111, 7.9)
# ('Central Alaska', 63.5141, -147.4529, 7.9)
# ('eastern Sichuan, China', 31.002, 103.322, 7.9)
# ('South Indian Ocean', -13.802, 97.453, 7.9)
# ('19km SE of Little Sitkin Island, Alaska', 51.8486, 178.7352, 7.9)
# ('54km NNE of Amberley, New Zealand', -42.7373, 173.054, 7.8)
# ('27km SSE of Muisne, Ecuador', 0.3819, -79.9218, 7.8)
# ('Tarapaca, Chile', -19.987, -69.197, 7.8)
# ('Haida Gwaii, Canada', 52.788, -132.101, 7.8)
# ('189km WNW of Chichi-shima, Japan', 27.8386, 140.4931, 7.8)
# ('36km E of Khudi, Nepal', 28.2305, 84.7314, 7.8)
# ('Rat Islands, Aleutian Islands, Alaska', 51.146, 178.65, 7.8)
# ('Southwest of Sumatra, Indonesia', -4.9521, 94.3299, 7.8)
# ('69km WSW of Kirakira, Solomon Islands', -10.6812, 161.3273, 7.8)
# ('south of the Fiji Islands', -25.996, -177.514, 7.8)
# ('southern Qinghai, China', 35.946, 90.541, 7.8)
# ('New Ireland region, Papua New Guinea', -5.233, 153.102, 7.8)
# ('off the west coast of the South Island of New Zealand', -45.762, 166.562, 7.8)
# ('Kepulauan Mentawai region, Indonesia', -3.487, 100.082, 7.8)
# ('northern Sumatra, Indonesia', 2.383, 97.048, 7.8)
# ('New Britain region, Papua New Guinea', -5.496, 151.781, 7.8)
# ('99 km SSE of Perryville, Alaska', 55.0715, -158.596, 7.8)
# ('Santa Cruz Islands', -12.517, 166.382, 7.8)
# ('123km NNW of Lucea, Jamaica', 19.4193, -78.756, 7.7)
# ('Sea of Okhotsk', 53.882, 152.886, 7.7)
# ('Vanuatu', -13.006, 166.51, 7.7)
# ('Sea of Okhotsk', 49.8, 145.064, 7.7)
# ('southeast of the Loyalty Islands', -23.0511, 171.6566, 7.7)
# ('offshore El Salvador', 13.049, -88.66, 7.7)
# ('near the north coast of Papua, Indonesia', -0.414, 132.885, 7.7)
# ('south of Java, Indonesia', -9.284, 107.419, 7.7)
# ('Antofagasta, Chile', -22.247, -69.89, 7.7)
# ("202km ESE of Nikol'skoye, Russia", 54.4434, 168.857, 7.7)
# ('south of the Fiji Islands', -23.884, 178.495, 7.7)
# ('83km E of Khash, Iran', 28.033, 61.996, 7.7)
# ('29km SW of Agrihan, Northern Mariana Islands', 18.5429, 145.5073, 7.7)
# ('Fiji region', -21.696, -179.513, 7.7)
# ('53km SW of Iquique, Chile', -20.5709, -70.4931, 7.7)
# ('off the east coast of Honshu, Japan', 38.058, 144.59, 7.7)
# ('Gujarat, India', 23.419, 70.232, 7.7)
# ('61km NNE of Awaran, Pakistan', 26.951, 65.5009, 7.7)
# ('Scotia Sea', -60.2738, -46.4011, 7.7)
# ('93km SSE of Kirakira, Solomon Islands', -11.2701, 162.1481, 7.6)
# ('99 km SE of Sand Point, Alaska', 54.602, -159.6258, 7.6)
# ('Tonga region', -23.043, -174.66, 7.6)
# ('Volcano Islands, Japan region', 22.338, 143.73, 7.6)
# ('Philippine Islands region', 10.811, 126.638, 7.6)
# ('Costa Rica', 10.085, -85.315, 7.6)
# ('New Ireland region, Papua New Guinea', -4.539, 153.474, 7.6)
# ('Pakistan', 34.539, 73.588, 7.6)
# ('offshore Colima, Mexico', 18.77, -104.104, 7.6)
# ('Banda Sea', -5.473, 128.131, 7.6)
# ('near the east coast of Koryakskiy Avtonomnyy Okrug, Russia', 60.949, 167.089, 7.6)
# ('southern Sumatra, Indonesia', -0.72, 99.867, 7.6)
# ('Scotia Sea', -60.532, -43.411, 7.6)
# ('46km SSE of Namatanai, Papua New Guinea', -4.051, 152.5967, 7.6)
# ('Carlsberg Ridge', -2.598, 68.382, 7.6)
# ('173km WNW of Iberia, Peru', -10.5372, -70.9437, 7.6)
# ('211km S of Tarauaca, Brazil', -10.0598, -71.0184, 7.6)
# ('Kermadec Islands region', -29.539, -176.34, 7.6)
# ('near the north coast of Papua, Indonesia', -1.757, 134.297, 7.6)
# ('near the north coast of New Guinea, Papua New Guinea', -3.302, 142.945, 7.6)
# ('Moro Gulf, Mindanao, Philippines', 6.497, 123.48, 7.6)
# ('near the coast of southern Peru', -17.543, -72.077, 7.6)
# ('41km SW of Puerto Quellon, Chile', -43.4064, -73.9413, 7.6)
# ('Sulawesi, Indonesia', -1.105, 123.573, 7.6)
# ('Java, Indonesia', -5.859, 107.419, 7.5)
# ('Southeastern Alaska', 55.228, -134.8591, 7.5)
# ('northern Peru', -5.678, -76.398, 7.5)
# ('Andaman Islands, India region', 14.099, 92.902, 7.5)
# ('Molucca Sea', 1.065, 126.282, 7.5)
# ('Nicobar Islands, India region', 7.881, 91.936, 7.5)
# ('Volcano Islands, Japan region', 22.013, 142.668, 7.5)
# ('Moro Gulf, Mindanao, Philippines', 6.776, 123.259, 7.5)
# ('Kepulauan Alor, Indonesia', -8.152, 124.868, 7.5)
# ('Banda Sea', -4.102, 123.907, 7.5)
# ('165km ESE of Tadine, New Caledonia', -21.9496, 169.4266, 7.5)
# ('53km SE of Kokopo, Papua New Guinea', -4.7294, 152.5623, 7.5)
# ('Mindanao, Philippines', 6.898, 126.579, 7.5)
# ('111km ESE of Palora, Ecuador', -2.1862, -77.0505, 7.5)
# ('70km SW of Panguna, Papua New Guinea', -6.7547, 155.0241, 7.5)
# ("221km SSE of Severo-Kuril'sk, Russia", 48.9638, 157.6955, 7.5)
# ('45km E of Farkhar, Afghanistan', 36.5244, 70.3676, 7.5)
# ('44km E of Great Swan Island, Honduras', 17.4825, -83.52, 7.5)
# ('130km SSW of Kokopo, Papua New Guinea', -5.4624, 151.8751, 7.5)
# ('Mindanao, Philippines', 6.033, 124.249, 7.5)
# ('70km N of Palu, Indonesia', -0.2559, 119.8462, 7.5)
# ('83km SW of Porgera, Papua New Guinea', -6.0699, 142.7536, 7.5)
# ('southern Sumatra, Indonesia', -4.68, 102.562, 7.4)
# ('Simeulue, Indonesia', 2.824, 96.085, 7.4)
# ('South Georgia Island region', -55.2852, -31.8766, 7.4)
# ('Auckland Islands, New Zealand region', -49.271, 164.115, 7.4)
# ('Kermadec Islands region', -31.81, -179.307, 7.4)
# ('off the coast of Bio-Bio, Chile', -37.773, -75.048, 7.4)
# ('282km SW of Vaini, Tonga', -23.009, -177.232, 7.4)
# ('Kermadec Islands region', -28.993, -176.238, 7.4)
# ('Hokkaido, Japan region', 41.774, 143.593, 7.4)
# ('Bonin Islands, Japan region', 26.901, 143.698, 7.4)
# ('Martinique region, Windward Islands', 14.944, -61.274, 7.4)
# ('Hindu Kush region, Afghanistan', 36.502, 70.482, 7.4)
# ('east of the South Sandwich Islands', -60.957, -21.606, 7.4)
# ('south of the Kermadec Islands', -33.2927, -177.8571, 7.4)
# ('Kermadec Islands, New Zealand', -29.6768, -177.8398, 7.4)
# ('near the north coast of Papua, Indonesia', -0.691, 133.305, 7.4)
# ('east of the Kuril Islands', 46.857, 155.154, 7.4)
# ('9 km SE of Santa Mar�a Xadani, Mexico', 15.8861, -96.0077, 7.4)
# ('Minahasa, Sulawesi, Indonesia', 1.271, 122.091, 7.4)
# ('Oaxaca, Mexico', 16.493, -98.231, 7.4)
# ('112km S of Kirakira, Solomon Islands', -11.4633, 162.0511, 7.4)
# ('near the south coast of Honshu, Japan', 33.184, 137.071, 7.4)
# ('offshore Guatemala', 13.988, -91.895, 7.4)
# ('Bonin Islands, Japan region', 28.856, 139.556, 7.4)
# ('Vanuatu', -13.093, 166.497, 7.4)
# ('Simeulue, Indonesia', 2.768, 95.964, 7.4)
# ('Loyalty Islands, New Caledonia', -20.071, 168.892, 7.3)
# ("83km W of Nikol'skoye, Russia", 55.0999, 164.6993, 7.3)
# ('offshore Honduras', 16.731, -86.217, 7.3)
# ('292km NW of Saumlaki, Indonesia', -6.4078, 129.1692, 7.3)
# ('New Britain region, Papua New Guinea', -5.931, 150.59, 7.3)
# ('Moro Gulf, Mindanao, Philippines', 6.718, 123.409, 7.3)
# ('170 km NE of Gisborne, New Zealand', -37.5459, 179.3587, 7.3)
# ("116km NE of L'Esperance Rock, New Zealand", -30.6441, -178.0995, 7.3)
# ('24km ENE of Rio Caribe, Venezuela', 10.7731, -62.9019, 7.3)
# ('Fiji', -17.239, 178.331, 7.3)
# ('Vanuatu', -17.541, 168.069, 7.3)
# ('115km ENE of Taron, Papua New Guinea', -3.917, 153.927, 7.3)
# ('Sea of Okhotsk', 54.203, 154.322, 7.3)
# ('Solomon Islands', -10.491, 160.77, 7.3)
# ('off the east coast of Honshu, Japan', 37.89, 143.949, 7.3)
# ('southern Sumatra, Indonesia', -2.427, 103.981, 7.3)
# ('off the coast of El Salvador', 12.139, -88.59, 7.3)
# ('74km S of Intipuca, El Salvador', 12.5262, -88.1225, 7.3)
# ('near the south coast of Papua, Indonesia', -4.003, 135.023, 7.3)
# ('southeast of the Loyalty Islands', -22.015, 169.766, 7.3)
# ('southwestern Siberia, Russia', 50.038, 87.813, 7.3)
# ('Fiji region', -21.611, -179.528, 7.3)
# ('19km SE of Kodari, Nepal', 27.8087, 86.0655, 7.3)
# ('Colombia', 1.929, -76.362, 7.3)
# ('northwest of the Kuril Islands', 47.824, 146.209, 7.3)
# ('Fox Islands, Aleutian Islands, Alaska', 52.05, -171.836, 7.3)
# ('Jilin-Heilongjiang border region, China', 43.752, 130.666, 7.3)
# ('near the east coast of Honshu, Japan', 38.435, 142.842, 7.3)
# ('189km SSE of Tabiauan, Philippines', 4.4782, 122.6171, 7.3)
# ('218km SSE of Bristol Island, South Sandwich Islands', -60.857, -25.07, 7.3)
# ('29km S of Halabjah, Iraq', 34.9109, 45.9592, 7.3)
# ('Vanuatu region', -19.702, 167.947, 7.3)
# ('near the south coast of western Honshu, Japan', 33.07, 136.618, 7.2)
# ('near the west coast of Colombia', 4.695, -77.508, 7.2)
# ('Jujuy, Argentina', -23.548, -66.452, 7.2)
# ('Nicobar Islands, India region', 7.92, 92.19, 7.2)
# ('near the east coast of Honshu, Japan', 38.276, 142.039, 7.2)
# ('Nicobar Islands, India region', 6.91, 92.958, 7.2)
# ('off the coast of Northern California', 41.292, -125.953, 7.2)
# ('Santa Cruz Islands', -11.61, 165.762, 7.2)
# ('Xinjiang-Xizang border region', 35.49, 81.467, 7.2)
# ('Vanuatu', -17.6, 167.856, 7.2)
# ('Fiji region', -19.926, -178.178, 7.2)
# ('Andreanof Islands, Aleutian Islands, Alaska', 51.36, -179.509, 7.2)
# ('South Island of New Zealand', -45.104, 167.144, 7.2)
# ('Pagan region, Northern Mariana Islands', 18.9, 145.388, 7.2)
# ('Kermadec Islands, New Zealand', -29.666, -178.633, 7.2)
# ('Vanuatu', -15.595, 167.68, 7.2)
# ('Kepulauan Mentawai region, Indonesia', -2.486, 99.972, 7.2)
# ('Tonga', -16.925, -174.248, 7.2)
# ('88km N of Yelizovo, Russia', 53.9776, 158.5463, 7.2)
# ('12km SW of Delta, B.C., MX', 32.2861667, -115.2953333, 7.2)
# ("251km ENE of Kuril'sk, Russia", 46.221, 150.788, 7.2)
# ('off the west coast of northern Sumatra', 2.433, 93.21, 7.2)
# ('3km S of San Pedro Jicayan, Mexico', 16.3855, -97.9787, 7.2)
# ('Vanuatu', -18.365, 168.143, 7.2)
# ('33km ESE of Petatlan, Mexico', 17.397, -100.9723, 7.2)
# ('southwestern Pakistan', 28.777, 63.951, 7.2)
# ('93km NNE of Laiwui, Indonesia', -0.5858, 128.034, 7.2)
# ('Vanuatu', -13.698, 166.643, 7.2)
# ('northern Sumatra, Indonesia', 3.748, 96.018, 7.2)
# ('Araucania, Chile', -38.355, -73.326, 7.2)
# ('53km NNE of Visokoi Island, South Georgia and the South Sandwich Islands', -56.2409, -26.9353, 7.2)
# ('110km E of Ile Hunter, New Caledonia', -22.4765, 173.1167, 7.2)
# ('Kepulauan Talaud, Indonesia', 3.886, 126.387, 7.2)
# ('104km W of Murghob, Tajikistan', 38.2107, 72.7797, 7.2)
# ('4km SE of Sagbayan, Philippines', 9.8796, 124.1167, 7.1)
# ('Off the east coast of Honshu, Japan', 37.1557, 144.6611, 7.1)
# ('off the west coast of the South Island of New Zealand', -46.676, 164.721, 7.1)
# ('Papua, Indonesia', -3.609, 135.404, 7.1)
# ('east of the North Island of New Zealand', -36.813, -179.575, 7.1)
# ('North of Ascension Island', -0.0456, -17.8255, 7.1)
# ('86km E of Old Iliamna, Alaska', 59.6204, -153.3392, 7.1)
# ('Southeast Indian Ridge', -47.6165, 85.0913, 7.1)
# ('46km SSE of Acari, Peru', -15.8385, -74.5112, 7.1)
# ('140km WNW of Iberia, Peru', -11.0355, -70.8284, 7.1)
# ('Celebes Sea', 5.293, 123.337, 7.1)
# ('Banda Sea', -6.527, 129.933, 7.1)
# ('56km WSW of Panguna, Papua New Guinea', -6.5858, 155.0485, 7.1)
# ('34km NE of Port-Olry, Vanuatu', -14.8595, 167.3028, 7.1)
# ('Amazonas, Brazil', -7.606, -71.722, 7.1)
# ('38km SSW of Acari, Peru', -15.7675, -74.7092, 7.1)
# ('144km NE of Ndoi Island, Fiji', -19.6903, -177.7587, 7.1)
# ('south of Australia', -42.813, 124.688, 7.1)
# ('Rat Islands, Aleutian Islands, Alaska', 51.272, 177.978, 7.1)
# ('southeast of the Loyalty Islands', -22.253, 169.683, 7.1)
# ('31km SE of Lata, Solomon Islands', -10.928, 166.018, 7.1)
# ('154km NW of Kota Ternate, Indonesia', 1.8929, 126.5217, 7.1)
# ('Northern Mid-Atlantic Ridge', 52.6487, -31.9016, 7.1)
# ('1km E of Ayutla, Mexico', 18.5499, -98.4887, 7.1)
# ('143km SW of Panguna, Papua New Guinea', -7.2175, 154.5567, 7.1)
# ('Taiwan region', 24.279, 122.179, 7.1)
# ('Guam region', 13.088, 144.619, 7.1)
# ('202km WNW of Ile Hunter, New Caledonia', -22.0295, 170.1262, 7.1)
# ('Fiji region', -17.656, -178.76, 7.1)
# ('33km NW of Bulolo, Papua New Guinea', -6.9746, 146.4494, 7.1)
# ('Taiwan region', 21.799, 120.547, 7.1)
# ('Vanuatu region', -19.528, 173.818, 7.1)
# ('69 km ENE of Namie, Japan', 37.7534, 141.7145, 7.1)
# ('Macquarie Island region', -55.664, 158.453, 7.1)
# ('near the south coast of Honshu, Japan', 33.167, 137.944, 7.1)
# ('Solomon Islands', -8.783, 157.354, 7.1)
# ('138km E of Bitung, Indonesia', 1.6213, 126.4156, 7.1)
# ('Ecuador', -1.266, -77.306, 7.1)
# ('2019 Ridgecrest Earthquake Sequence', 35.7695, -117.5993333, 7.1)
# ('114km WSW of Lata, Solomon Islands', -11.183, 164.882, 7.1)
# ('Vanuatu', -20.617, 169.357, 7.1)
# ('near the east coast of Honshu, Japan', 38.276, 141.588, 7.1)
# ('Banda Sea', -6.533, 129.825, 7.1)
# ('eastern New Guinea region, Papua New Guinea', -7.551, 146.809, 7.1)
# ('Molucca Sea', 1.271, 126.249, 7.1)
# ('Maule, Chile', -35.2, -72.217, 7.1)
# ('Vanuatu', -14.928, 167.17, 7.1)
# ('14km NNW of Anchorage, Alaska', 61.3464, -149.9552, 7.1)
# ('eastern Turkey', 38.721, 43.508, 7.1)
# ('54km N of Bristol Island, South Sandwich Islands', -58.5446, -26.3856, 7.1)
# ('Vanuatu', -17.827, 167.133, 7.1)
# ('Vanuatu', -18.311, 168.218, 7.1)
# ('114 km NNW of Popondetta, Papua New Guinea', -7.836, 147.7704, 7.0)
# ('1km E of Kumamoto-shi, Japan', 32.7906, 130.7543, 7.0)
# ('2km N of Norsup, Vanuatu', -16.0429, 167.3786, 7.0)
# ('Santiago Del Estero, Argentina', -28.307, -62.99, 7.0)
# ('211 km SE of Pondaguitan, Philippines', 4.9931, 127.5145, 7.0)
# ('13 km NNE of N�on Karlov�sion, Greece', 37.8973, 26.7838, 7.0)
# ('23km NNE of Azangaro, Peru', -14.7131, -70.1546, 7.0)
# ("94km ENE of Kuril'sk, Russia", 45.6161, 148.959, 7.0)
# ('175km NE of Gisborne, New Zealand', -37.3586, 179.1461, 7.0)
# ('Vanuatu', -15.421, 166.91, 7.0)
# ('85km ENE of Tadine, New Caledonia', -21.3246, 168.6715, 7.0)
# ('New Ireland region, Papua New Guinea', -4.766, 153.945, 7.0)
# ('96km ESE of Pondaguitan, Philippines', 5.8983, 126.9209, 7.0)
# ('Guam region', 12.686, 144.98, 7.0)
# ('Turkmenistan', 39.566, 54.799, 7.0)
# ('New Britain region, Papua New Guinea', -5.912, 150.196, 7.0)
# ('118km E of Kimbe, Papua New Guinea', -5.7012, 151.2046, 7.0)
# ('Kermadec Islands, New Zealand', -29.756, -177.683, 7.0)
# ('Rat Islands, Aleutian Islands, Alaska', 50.3298, 177.5472, 7.0)
# ('Kepulauan Mentawai region, Indonesia', -2.13, 99.627, 7.0)
# ('northern Peru', -7.641, -74.525, 7.0)
# ('Scotia Sea', -61.029, -34.371, 7.0)
# ('off the east coast of Honshu, Japan', 38.034, 143.264, 7.0)
# ('Loyalty Islands, New Caledonia', -20.628, 168.471, 7.0)
# ('Santiago Del Estero, Argentina', -26.803, -63.136, 7.0)
# ('near the south coast of Papua, Indonesia', -4.963, 133.76, 7.0)
# ('South Island of New Zealand', -43.522, 171.83, 7.0)
# ('New Britain region, Papua New Guinea', -5.746, 150.765, 7.0)
# ('Mozambique', -21.324, 33.583, 7.0)
# ('near the north coast of Papua, Indonesia', -2.174, 136.543, 7.0)
# ("Libertador General Bernardo O'Higgins, Chile", -34.326, -71.799, 7.0)
# ('Ryukyu Islands, Japan', 25.93, 128.425, 7.0)
# ('Haiti region', 18.443, -72.571, 7.0)
# ('Java, Indonesia', -7.782, 107.297, 7.0)
# ('Kermadec Islands region', -27.424, -176.33, 7.0)
# ('South Sandwich Islands region', -58.227, -22.099, 7.0)
# ('Vanuatu', -20.671, 169.716, 7.0)
# ('off the east coast of Honshu, Japan', 38.107, 144.896, 7.0)
# ('near the east coast of Honshu, Japan', 38.849, 141.568, 7.0)
# ('Papua, Indonesia', -3.615, 135.538, 7.0)
# ('Halmahera, Indonesia', 2.354, 128.855, 7.0)
# ('25km WNW of Illapel, Chile', -31.5622, -71.4262, 7.0)
# ('228km W of Abepura, Indonesia', -2.6286, 138.5277, 7.0)
# ('83km WNW of Lata, Solomon Islands', -10.4012, 165.1409, 7.0)
# ('Southern Mid-Atlantic Ridge', -35.3639, -17.1605, 7.0)
# ('130km N of Nebe, Indonesia', -7.2968, 122.5348, 7.0)
# ('off the east coast of Honshu, Japan', 37.812, 142.619, 7.0)
# ('off the east coast of Honshu, Japan', 37.552, 142.214, 7.0)
# ('Baja California, Mexico', 28.696, -113.104, 7.0)
# ('Southern East Pacific Rise', -32.1082, -110.8112, 7.0)
# ('near the coast of Nicaragua', 11.422, -86.665, 7.0)
# ('Falkland Islands region', -53.9451, -55.0033, 7.0)
# ('Hokkaido, Japan region', 43.006, 145.119, 7.0)
# ('101km SW of Atka, Alaska', 51.537, -175.2297, 7.0)
# ('240km E of Enarotali, Indonesia', -3.517, 138.476, 7.0)
# ('27km NNW of Lata, Solomon Islands', -10.499, 165.588, 7.0)
# ('29 km ENE of Ishinomaki, Japan', 38.4754, 141.6328, 7.0)

# %%
for row in session.query(gdp.Country, gdp.Longitude, gdp.Latitude, gdp.Magnitude).all():
    print(row)
