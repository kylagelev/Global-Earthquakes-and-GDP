# %% [markdown]
# # Data Cleaning and Exploration
#
# #### Purpose
# - Use Earthquake API to get Earthquake data used for visualization and analysis
# - Manipulate JSON response into a usable dataframe that can be exported out into csv
# - Sort by Magnitude to identify Top 5 Earthquakes which will be our focus for visualizations page
#
# #### API
# https://earthquake.usgs.gov/fdsnws/event/1/
#
# #### Parameters
# - Format: geojson
# - Start Time: 2000-01-01
# - End Time: Present (default)
# - Minimum Magnitude: 7

# %%
# Dependencies and Setup
import json
import matplotlib.pyplot as plt
import pandas as pd
from pandas import json_normalize
import numpy as np
import requests
import time
from scipy.stats import linregress
from pprint import pprint

# %%
# Perform API Call to get json data for earthquakes from 2000 to current
url = "https://earthquake.usgs.gov/fdsnws/event/1/query?format=geojson&starttime=2000-01-01&minmagnitude=7"
response = requests.get(url).json()

# %%
print(response)
# Out:
# {'type': 'FeatureCollection', 'metadata': {'generated': 1618375440000, 'url': 'https://earthquake.usgs.gov/fdsnws/event/1/query?format=geojson&starttime=2000-01-01&minmagnitude=7', 'title': 'USGS Earthquakes', 'status': 200, 'api': '1.10.3', 'count': 320}, 'features': [{'type': 'Feature', 'properties': {'mag': 7, 'place': '27 km ENE of Ishinomaki, Japan', 'time': 1616231385279, 'updated': 1618024615789, 'tz': None, 'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us7000dl6y', 'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us7000dl6y&format=geojson', 'felt': 408, 'cdi': 7.3, 'mmi': 6.668, 'alert': 'yellow', 'status': 'reviewed', 'tsunami': 1, 'sig': 1052, 'net': 'us', 'code': '7000dl6y', 'ids': ',at00qq9g49,us7000dl6y,usauto7000dl6y,pt21079003,', 'sources': ',at,us,usauto,pt,', 'types': ',associate,dyfi,finite-fault,general-text,ground-failure,impact-link,internal-moment-tensor,internal-origin,losspager,moment-tensor,origin,phase-data,shakemap,', 'nst': None, 'dmin': 2.349, 'rms': 1.03, 'gap': 60, 'magType': 'mww', 'type': 'earthquake', 'title': 'M 7.0 - 27 km ENE of Ishinomaki, Japan'}, 'geometry': {'type': 'Point', 'coordinates': [141.6069, 38.4752, 54]}, 'id': 'us7000dl6y'}, {'type': 'Feature', 'properties': {'mag': 8.1, 'place': 'Kermadec Islands, New Zealand', 'time': 1614886113176, 'updated': 1617962734576, 'tz': None, 'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us7000dflf', 'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us7000dflf&format=geojson', 'felt': 13, 'cdi': 9.1, 'mmi': 8.038, 'alert': 'green', 'status': 'reviewed', 'tsunami': 1, 'sig': 1021, 'net': 'us', 'code': '7000dflf', 'ids': ',at00qpgm3n,pt21063003,us7000dflf,usauto7000dflf,', 'sources': ',at,pt,us,usauto,', 'types': ',associate,dyfi,finite-fault,general-text,impact-link,impact-text,internal-moment-tensor,internal-origin,losspager,moment-tensor,origin,phase-data,shakemap,', 'nst': None, 'dmin': 0.74, 'rms': 0.69, 'gap': 21, 'magType': 'mww', 'type': 'earthquake', 'title': 'M 8.1 - Kermadec Islands, New Zealand'}, 'geometry': {'type': 'Point', 'coordinates': [-177.2791, -29.7226, 28.94]}, 'id': 'us7000dflf'}, {'type': 'Feature', 'properties': {'mag': 7.4, 'place': 'Kermadec Islands, New Zealand', 'time': 1614879683379, 'updated': 1616682204914, 'tz': None, 'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us7000dfk3', 'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us7000dfk3&format=geojson', 'felt': 2, 'cdi': 2, 'mmi': 6.815, 'alert': 'green', 'status': 'reviewed', 'tsunami': 1, 'sig': 843, 'net': 'us', 'code': '7000dfk3', 'ids': ',us7000dfk3,pt21063002,at00qpgh52,usauto7000dfk3,', 'sources': ',us,pt,at,usauto,', 'types': ',dyfi,finite-fault,general-text,impact-link,impact-text,internal-moment-tensor,internal-origin,losspager,moment-tensor,origin,phase-data,shakemap,', 'nst': None, 'dmin': 0.436, 'rms': 1.1, 'gap': 30, 'magType': 'mww', 'type': 'earthquake', 'title': 'M 7.4 - Kermadec Islands, New Zealand'}, 'geometry': {'type': 'Point', 'coordinates': [-177.8415, -29.6762, 43]}, 'id': 'us7000dfk3'}, {'type': 'Feature', 'properties': {'mag': 7.3, 'place': '170 km NE of Gisborne, New Zealand', 'time': 1614864454885, 'updated': 1618087095273, 'tz': None, 'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us7000dffl', 'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us7000dffl&format=geojson', 'felt': 158, 'cdi': 7.3, 'mmi': 6.531, 'alert': 'green', 'status': 'reviewed', 'tsunami': 1, 'sig': 935, 'net': 'us', 'code': '7000dffl', 'ids': ',us7000dffl,at00qpg5dz,pt21063000,usauto7000dffl,', 'sources': ',us,at,pt,usauto,', 'types': ',associate,dyfi,general-text,ground-failure,impact-link,impact-text,internal-moment-tensor,internal-origin,losspager,moment-tensor,origin,phase-data,shakemap,', 'nst': None, 'dmin': 3.956, 'rms': 0.92, 'gap': 26, 'magType': 'mww', 'type': 'earthquake', 'title': 'M 7.3 - 170 km NE of Gisborne, New Zealand'}, 'geometry' ...

# %%
pprint(response)
# Out:
# {'bbox': [-179.575, -61.029, 4.2, 179.3587, 63.5141, 675.4],
#  'features': [{'geometry': {'coordinates': [141.6069, 38.4752, 54],
#                             'type': 'Point'},
#                'id': 'us7000dl6y',
#                'properties': {'alert': 'yellow',
#                               'cdi': 7.3,
#                               'code': '7000dl6y',
#                               'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us7000dl6y&format=geojson',
#                               'dmin': 2.349,
#                               'felt': 408,
#                               'gap': 60,
#                               'ids': ',at00qq9g49,us7000dl6y,usauto7000dl6y,pt21079003,',
#                               'mag': 7,
#                               'magType': 'mww',
#                               'mmi': 6.668,
#                               'net': 'us',
#                               'nst': None,
#                               'place': '27 km ENE of Ishinomaki, Japan',
#                               'rms': 1.03,
#                               'sig': 1052,
#                               'sources': ',at,us,usauto,pt,',
#                               'status': 'reviewed',
#                               'time': 1616231385279,
#                               'title': 'M 7.0 - 27 km ENE of Ishinomaki, Japan',
#                               'tsunami': 1,
#                               'type': 'earthquake',
#                               'types': ',associate,dyfi,finite-fault,general-text,ground-failure,impact-link,internal-moment-tensor,internal-origin,losspager,moment-tensor,origin,phase-data,shakemap,',
#                               'tz': None,
#                               'updated': 1618024615789,
#                               'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us7000dl6y'},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [-177.2791, -29.7226, 28.94],
#                             'type': 'Point'},
#                'id': 'us7000dflf',
#                'properties': {'alert': 'green',
#                               'cdi': 9.1,
#                               'code': '7000dflf',
#                               'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us7000dflf&format=geojson',
#                               'dmin': 0.74,
#                               'felt': 13,
#                               'gap': 21,
#                               'ids': ',at00qpgm3n,pt21063003,us7000dflf,usauto7000dflf,',
#                               'mag': 8.1,
#                               'magType': 'mww',
#                               'mmi': 8.038,
#                               'net': 'us',
#                               'nst': None,
#                               'place': 'Kermadec Islands, New Zealand',
#                               'rms': 0.69,
#                               'sig': 1021,
#                               'sources': ',at,pt,us,usauto,',
#                               'status': 'reviewed',
#                               'time': 1614886113176,
#                               'title': 'M 8.1 - Kermadec Islands, New Zealand',
#                               'tsunami': 1,
#                               'type': 'earthquake',
#                               'types': ',associate,dyfi,finite-fault,general-text,impact-link,impact-text,internal-moment-tensor,internal-origin,losspager,moment-tensor,origin,phase-data,shakemap,',
#                               'tz': None,
#                               'updated': 1617962734576,
#                               'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us7000dflf'},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [-177.8415, -29.6762, 43],
#                             'type': 'Point'},
#                'id': 'us7000dfk3',
#                'properties': {'alert': 'green',
#                               'cdi': 2,
#                               'code': '7000dfk3',
#                               'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us7000dfk3&format=geojson',
#                               'dmin': 0.436,
#                               'felt': 2,
#                               'gap': 30,
#                               'ids': ',us7000dfk3,pt21063002,at00qpgh52,usauto7000dfk3,',
#                               'mag': 7.4,
#                               'magType': 'mww',
#                               'mmi': 6.815,
#                               'net': 'us',
#                               'nst': None,
#                               'place': 'Kermadec Islands, New Zealand',
#                               'rms': 1.1,
#                               'sig': 843,
#                               'sources': ',us,pt,at,usauto,',
#                               'status': 'reviewed',
#                               'time': 1614879683379,
#                               'title': 'M 7.4 - Kermadec Islands, New Zealand',
#                               'tsunami': 1,
#                               'type': 'earthquake',
#                               'types': ',dyfi,finite-fault,general-text,impact-link,impact-text,internal-moment-tensor,internal-origin,losspager,moment-tensor,origin,phase-data,shakemap,',
#                               'tz': None,
#                               'updated': 1616682204914,
#                               'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us7000dfk3'},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [179.3587, -37.5459, 10],
#                             'type': 'Point'},
#                'id': 'us7000dffl',
#                'properties': {'alert': 'green',
#                               'cdi': 7.3,
#                               'code': '7000dffl',
#                               'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us7000dffl&format=geojson',
#                               'dmin': 3.956,
#                               'felt': 158,
#                               'gap': 26,
#                               'ids': ',us7000dffl,at00qpg5dz,pt21063000,usauto7000dffl,',
#                               'mag': 7.3,
#                               'magType': 'mww',
#                               'mmi': 6.531,
#                               'net': 'us',
#                               'nst': None,
#                               'place': '170 km NE of Gisborne, New Zealand',
#                               'rms': 0.92,
#                               'sig': 935,
#                               'sources': ',us,at,pt,usauto,',
#                               'status': 'reviewed',
#                               'time': 1614864454885,
#                               'title': 'M 7.3 - 170 km NE of Gisborne, New '
#                                        'Zealand',
#                               'tsunami': 1,
#                               'type': 'earthquake',
#                               'types': ',associate,dyfi,general-text,ground-failure,impact-link,impact-text,internal-moment-tensor,internal-origin,losspager,moment-tensor,origin,phase-data,shakemap,',
#                               'tz': None,
#                               'updated': 1618087095273,
#                               'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us7000dffl'},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [141.7145, 37.7534, 44.07],
#                             'type': 'Point'},
#                'id': 'us6000dher',
#                'properties': {'alert': 'orange',
#                               'cdi': 9.1,
#                               'code': '6000dher',
#                               'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us6000dher&format=geojson',
#                               'dmin': 3.05,
#                               'felt': 674,
#                               'gap': 25,
#                               'ids': ',at00qoh0l1,us6000dher,pt21044000,',
#                               'mag': 7.1,
#                               'magType': 'mww',
#                               'mmi': 8.115,
#                               'net': 'us',
#                               'nst': None,
#                               'place': '69 km ENE of Namie, Japan',
#                               'rms': 0.95,
#                               'sig': 1613,
#                               'sources': ',at,us,pt,',
#                               'status': 'reviewed',
#                               'time': 1613225270194,
#                               'title': 'M 7.1 - 69 km ENE of Namie, Japan',
#                               'tsunami': 1,
#                               'type': 'earthquake',
#                               'types': ',associate,dyfi,finite-fault,general-text,ground-failure,impact-link,impact-text,internal-origin,losspager,moment-tensor,origin,phase-data,shakemap,',
#                               'tz': None,
#                               'updated': 1616865476989,
#                               'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us6000dher'},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [171.6565, -23.051, 10],
#                             'type': 'Point'},
#                'id': 'us6000dg77',
#                'properties': {'alert': 'green',
#                               'cdi': 7,
#                               'code': '6000dg77',
#                               'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us6000dg77&format=geojson',
#                               'dmin': 7.989,
#                               'felt': 25,
#                               'gap': 15,
#                               'ids': ',us6000dg77,at00qobedd,pt21041004,',
#                               'mag': 7.7,
#                               'magType': 'mww',
#                               'mmi': 4.349,
#                               'net': 'us',
#                               'nst': None,
#                               'place': 'southeast of the Loyalty Islands',
#                               'rms': 0.42,
#                               'sig': 930,
#                               'sources': ',us,at,pt,',
#                               'status': 'reviewed',
#                               'time': 1612963195531,
#                               'title': 'M 7.7 - southeast of the Loyalty '
#                                        'Islands',
#                               'tsunami': 1,
#                               'type': 'earthquake',
#                               'types': ',dyfi,finite-fault,general-text,ground-failure,impact-link,impact-text,internal-origin,losspager,moment-tensor,origin,phase-data,shakemap,',
#                               'tz': None,
#                               'updated': 1616081807620,
#                               'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us6000dg77'},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [127.5145, 4.9931, 80],
#                             'type': 'Point'},
#                'id': 'us7000d20e',
#                'properties': {'alert': 'green',
#                               'cdi': 6.6,
#                               'code': '7000d20e',
#                               'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us7000d20e&format=geojson',
#                               'dmin': 2.821,
#                               'felt': 72,
#                               'gap': 15,
#                               'ids': ',pt21021050,at00qnaaek,us7000d20e,usauto7000d20e,',
#                               'mag': 7,
#                               'magType': 'mww',
#                               'mmi': 5.451,
#                               'net': 'us',
#                               'nst': None,
#                               'place': '211 km SE of Pondaguitan, Philippines',
#                               'rms': 0.77,
#                               'sig': 801,
#                               'sources': ',pt,at,us,usauto,',
#                               'status': 'reviewed',
#                               'time': 1611231784255,
#                               'title': 'M 7.0 - 211 km SE of Pondaguitan, '
#                                        'Philippines',
#                               'tsunami': 1,
#                               'type': 'earthquake',
#                               'types': ',dyfi,general-text,ground-failure,impact-link,impact-text,internal-moment-tensor,internal-origin,losspager,moment-tensor,origin,phase-data,shakemap,',
#                               'tz': None,
#                               'updated': 1617189951197,
#                               'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us7000d20e'},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [26.7838, 37.8973, 21],
#                             'type': 'Point'},
#                'id': 'us7000c7y0',
#                'properties': {'alert': 'orange',
#                               'cdi': 7.6,
#                               'code': '7000c7y0',
#                               'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us7000c7y0&format=geojson',
#                               'dmin': 1.518,
#                               'felt': 881,
#                               'gap': 18,
#                               'ids': ',us7000c7y0,pt20304000,at00qj0jlr,',
#                               'mag': 7,
#                               'magType': 'mww',
#                               'mmi': 7.044,
#                               'net': 'us',
#                               'nst': None,
#                               'place': '13 km NNE of Néon Karlovásion, Greece',
#                               'rms': 0.59,
#                               'sig': 1670,
#                               'sources': ',us,pt,at,',
#                               'status': 'reviewed',
#                               'time': 1604058687348,
#                               'title': 'M 7.0 - 13 km NNE of Néon Karlovásion, '
#                                        'Greece',
#                               'tsunami': 0,
#                               'type': 'earthquake',
#                               'types': ',dyfi,finite-fault,general-text,ground-failure,impact-text,internal-origin,losspager,moment-tensor,origin,phase-data,shakemap,',
#                               'tz': None,
#                               'updated': 1615485972051,
#                               'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us7000c7y0'},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [-159.6258, 54.602, 28.37],
#                             'type': 'Point'},
#                'id': 'us6000c9hg',
#                'properties': {'alert': 'yellow',
#                               'cdi': 8.6,
#                               'code': '6000c9hg',
#                               'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us6000c9hg&format=geojson',
#                               'dmin': 0.23,
#                               'felt': 321,
#                               'gap': 36,
#                               'ids': ',at00qigvf4,us6000c9hg,pt20293005,ak020dgwp0mk,',
#                               'mag': 7.6,
#                               'magType': 'mww',
#                               'mmi': 6.87,
#                               'net': 'us',
#                               'nst': None,
#                               'place': '99 km SE of Sand Point, Alaska',
#                               'rms': 0.91,
#                               'sig': 1165,
#                               'sources': ',at,us,pt,ak,',
#                               'status': 'reviewed',
#                               'time': 1603140878950,
#                               'title': 'M 7.6 - 99 km SE of Sand Point, Alaska',
#                               'tsunami': 1,
#                               'type': 'earthquake',
#                               'types': ',dyfi,finite-fault,general-text,ground-failure,impact-link,impact-text,internal-origin,losspager,moment-tensor,origin,phase-data,shakemap,trump-origin,',
#                               'tz': None,
#                               'updated': 1615823316759,
#                               'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us6000c9hg'},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [-158.596, 55.0715, 28],
#                             'type': 'Point'},
#                'id': 'us7000asvb',
#                'properties': {'alert': 'green',
#                               'cdi': 7.1,
#                               'code': '7000asvb',
#                               'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us7000asvb&format=geojson',
#                               'dmin': 0.621,
#                               'felt': 301,
#                               'gap': 60,
#                               'ids': ',at00qdux98,us7000asvb,pt20204000,ak0209dha24u,',
#                               'mag': 7.8,
#                               'magType': 'mww',
#                               'mmi': 6.501,
#                               'net': 'us',
#                               'nst': None,
#                               'place': '99 km SSE of Perryville, Alaska',
#                               'rms': 0.97,
#                               'sig': 1150,
#                               'sources': ',at,us,pt,ak,',
#                               'status': 'reviewed',
#                               'time': 1595398364810,
#                               'title': 'M 7.8 - 99 km SSE of Perryville, '
#                                        'Alaska',
#                               'tsunami': 1,
#                               'type': 'earthquake',
#                               'types': ',dyfi,finite-fault,general-link,general-text,ground-failure,impact-link,impact-text,internal-origin,losspager,moment-tensor,oaf,origin,phase-data,shakemap,trump-origin,trump-shakemap,',
#                               'tz': None,
#                               'updated': 1617776599782,
#                               'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us7000asvb'},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [147.7704, -7.836, 73],
#                             'type': 'Point'},
#                'id': 'us7000aq3e',
#                'properties': {'alert': 'green',
#                               'cdi': 6.4,
#                               'code': '7000aq3e',
#                               'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us7000aq3e&format=geojson',
#                               'dmin': 1.671,
#                               'felt': 103,
#                               'gap': 18,
#                               'ids': ',at00qdlek0,pt20199000,us7000aq3e,',
#                               'mag': 7,
#                               'magType': 'mww',
#                               'mmi': 7.001,
#                               'net': 'us',
#                               'nst': None,
#                               'place': '114 km NNW of Popondetta, Papua New '
#                                        'Guinea',
#                               'rms': 1.1,
#                               'sig': 820,
#                               'sources': ',at,pt,us,',
#                               'status': 'reviewed',
#                               'time': 1594954222178,
#                               'title': 'M 7.0 - 114 km NNW of Popondetta, '
#                                        'Papua New Guinea',
#                               'tsunami': 1,
#                               'type': 'earthquake',
#                               'types': ',dyfi,finite-fault,general-text,ground-failure,impact-link,impact-text,internal-origin,losspager,moment-tensor,origin,phase-data,shakemap,',
#                               'tz': None,
#                               'updated': 1602143563279,
#                               'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us7000aq3e'},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [-96.0077, 15.8861, 20],
#                             'type': 'Point'},
#                'id': 'us6000ah9t',
#                'properties': {'alert': 'orange',
#                               'cdi': 7.9,
#                               'code': '6000ah9t',
#                               'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us6000ah9t&format=geojson',
#                               'dmin': 0.151,
#                               'felt': 650,
#                               'gap': 30,
#                               'ids': ',at00qcdxol,pt20175001,us6000ah9t,',
#                               'mag': 7.4,
#                               'magType': 'mww',
#                               'mmi': 8.798,
#                               'net': 'us',
#                               'nst': None,
#                               'place': '9 km SE of Santa María Xadani, Mexico',
#                               'rms': 1.14,
#                               'sig': 1514,
#                               'sources': ',at,pt,us,',
#                               'status': 'reviewed',
#                               'time': 1592926144350,
#                               'title': 'M 7.4 - 9 km SE of Santa María Xadani, '
#                                        'Mexico',
#                               'tsunami': 1,
#                               'type': 'earthquake',
#                               'types': ',dyfi,finite-fault,general-link,general-text,geoserve,ground-failure,impact-link,impact-text,internal-origin,losspager,moment-tensor,origin,phase-data,shakemap,',
#                               'tz': -360,
#                               'updated': 1617846253384,
#                               'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us6000ah9t'},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [-177.8571, -33.2927, 10],
#                             'type': 'Point'},
#                'id': 'us6000ae4n',
#                'properties': {'alert': 'green',
#                               'cdi': 6.6,
#                               'code': '6000ae4n',
#                               'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us6000ae4n&format=geojson',
#                               'dmin': 4.035,
#                               'felt': 47,
#                               'gap': 23,
#                               'ids': ',at00qc4gz1,pt20170001,us6000ae4n,',
#                               'mag': 7.4,
#                               'magType': 'mww',
#                               'mmi': 6.954,
#                               'net': 'us',
#                               'nst': None,
#                               'place': 'south of the Kermadec Islands',
#                               'rms': 0.86,
#                               'sig': 873,
#                               'sources': ',at,pt,us,',
#                               'status': 'reviewed',
#                               'time': 1592484593844,
#                               'title': 'M 7.4 - south of the Kermadec Islands',
#                               'tsunami': 1,
#                               'type': 'earthquake',
#                               'types': ',dyfi,general-text,geoserve,impact-link,internal-origin,losspager,moment-tensor,origin,phase-data,shakemap,',
#                               'tz': -720,
#                               'updated': 1598745645040,
#                               'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us6000ae4n'},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [157.6955, 48.9638, 57.8],
#                             'type': 'Point'},
#                'id': 'us70008fi4',
#                'properties': {'alert': 'green',
#                               'cdi': 5.6,
#                               'code': '70008fi4',
#                               'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us70008fi4&format=geojson',
#                               'dmin': 4.109,
#                               'felt': 27,
#                               'gap': 12,
#                               'ids': ',at00q7qai7,pt20085000,us70008fi4,',
#                               'mag': 7.5,
#                               'magType': 'mww',
#                               'mmi': 5.235,
#                               'net': 'us',
#                               'nst': None,
#                               'place': "221km SSE of Severo-Kuril'sk, Russia",
#                               'rms': 0.66,
#                               'sig': 881,
#                               'sources': ',at,pt,us,',
#                               'status': 'reviewed',
#                               'time': 1585104561160,
#                               'title': "M 7.5 - 221km SSE of Severo-Kuril'sk, "
#                                        'Russia',
#                               'tsunami': 1,
#                               'type': 'earthquake',
#                               'types': ',dyfi,finite-fault,general-text,geoserve,ground-failure,impact-link,impact-text,internal-origin,losspager,moment-tensor,origin,phase-data,shakemap,',
#                               'tz': 660,
#                               'updated': 1592073892040,
#                               'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us70008fi4'},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [148.959, 45.6161, 143],
#                             'type': 'Point'},
#                'id': 'us70007pa9',
#                'properties': {'alert': 'yellow',
#                               'cdi': 4.8,
#                               'code': '70007pa9',
#                               'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us70007pa9&format=geojson',
#                               'dmin': 4.501,
#                               'felt': 33,
#                               'gap': 25,
#                               'ids': ',us70007pa9,at00q5myo9,at00q5mcj0,pt20044002,',
#                               'mag': 7,
#                               'magType': 'mww',
#                               'mmi': 6.255,
#                               'net': 'us',
#                               'nst': None,
#                               'place': "94km ENE of Kuril'sk, Russia",
#                               'rms': 0.83,
#                               'sig': 770,
#                               'sources': ',us,at,at,pt,',
#                               'status': 'reviewed',
#                               'time': 1581590024406,
#                               'title': "M 7.0 - 94km ENE of Kuril'sk, Russia",
#                               'tsunami': 1,
#                               'type': 'earthquake',
#                               'types': ',associate,dyfi,finite-fault,geoserve,ground-failure,impact-link,internal-origin,losspager,moment-tensor,origin,phase-data,shakemap,',
#                               'tz': 660,
#                               'updated': 1588457384040,
#                               'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us70007pa9'},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [-78.756, 19.4193, 14.86],
#                             'type': 'Point'},
#                'id': 'us60007idc',
#                'properties': {'alert': 'yellow',
#                               'cdi': 9,
#                               'code': '60007idc',
#                               'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us60007idc&format=geojson',
#                               'dmin': 1.657,
#                               'felt': 1540,
#                               'gap': 26,
#                               'ids': ',pt20028001,us60007idc,at00q4ttp1,',
#                               'mag': 7.7,
#                               'magType': 'mww',
#                               'mmi': 6,
#                               'net': 'us',
#                               'nst': None,
#                               'place': '123km NNW of Lucea, Jamaica',
#                               'rms': 0.75,
#                               'sig': 1812,
#                               'sources': ',pt,us,at,',
#                               'status': 'reviewed',
#                               'time': 1580238624918,
#                               'title': 'M 7.7 - 123km NNW of Lucea, Jamaica',
#                               'tsunami': 1,
#                               'type': 'earthquake',
#                               'types': ',dyfi,finite-fault,general-text,geoserve,ground-failure,impact-link,impact-text,losspager,losspager-admin,moment-tensor,origin,phase-data,poster,shakemap,',
#                               'tz': -300,
#                               'updated': 1612363833444,
#                               'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us60007idc'},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [126.4156, 1.6213, 33],
#                             'type': 'Point'},
#                'id': 'us60006bjl',
#                'properties': {'alert': 'green',
#                               'cdi': 5.8,
#                               'code': '60006bjl',
#                               'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us60006bjl&format=geojson',
#                               'dmin': 1.271,
#                               'felt': 41,
#                               'gap': 11,
#                               'ids': ',pt19318001,at00q0yvxj,us60006bjl,',
#                               'mag': 7.1,
#                               'magType': 'mww',
#                               'mmi': 6.459,
#                               'net': 'us',
#                               'nst': None,
#                               'place': '138km E of Bitung, Indonesia',
#                               'rms': 1.15,
#                               'sig': 799,
#                               'sources': ',pt,at,us,',
#                               'status': 'reviewed',
#                               'time': 1573748260578,
#                               'title': 'M 7.1 - 138km E of Bitung, Indonesia',
#                               'tsunami': 1,
#                               'type': 'earthquake',
#                               'types': ',dyfi,finite-fault,general-text,geoserve,ground-failure,impact-link,impact-text,losspager,moment-tensor,origin,phase-data,shakemap,',
#                               'tz': 480,
#                               'updated': 1601703531266,
#                               'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us60006bjl'},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [128.034, -0.5858, 18.98],
#                             'type': 'Point'},
#                'id': 'us70004jyv',
#                'properties': {'alert': 'green',
#                               'cdi': 6.7,
#                               'code': '70004jyv',
#                               'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us70004jyv&format=geojson',
#                               'dmin': 1.504,
#                               'felt': 17,
#                               'gap': 38,
#                               'ids': ',us70004jyv,',
#                               'mag': 7.2,
#                               'magType': 'mww',
#                               'mmi': 6.81,
#                               'net': 'us',
#                               'nst': None,
#                               'place': '93km NNE of Laiwui, Indonesia',
#                               'rms': 0.88,
#                               'sig': 809,
#                               'sources': ',us,',
#                               'status': 'reviewed',
#                               'time': 1563095451523,
#                               'title': 'M 7.2 - 93km NNE of Laiwui, Indonesia',
#                               'tsunami': 1,
#                               'type': 'earthquake',
#                               'types': ',dyfi,finite-fault,general-text,geoserve,ground-failure,impact-text,losspager,moment-tensor,origin,phase-data,poster,shakemap,',
#                               'tz': 540,
#                               'updated': 1596115886346,
#                               'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us70004jyv'},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [-117.5993333, 35.7695, 8],
#                             'type': 'Point'},
#                'id': 'ci38457511',
#                'properties': {'alert': 'yellow',
#                               'cdi': 8.2,
#                               'code': '38457511',
#                               'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=ci38457511&format=geojson',
#                               'dmin': 0.04616,
#                               'felt': 25863,
#                               'gap': 43,
#                               'ids': ',ci38457511,us70004bn0,at00pu7alg,pt19187000,,',
#                               'mag': 7.1,
#                               'magType': 'mw',
#                               'mmi': 8.73,
#                               'net': 'ci',
#                               'nst': 77,
#                               'place': '2019 Ridgecrest Earthquake Sequence',
#                               'rms': 0.22,
#                               'sig': 1596,
#                               'sources': ',ci,us,at,pt,,',
#                               'status': 'reviewed',
#                               'time': 1562383193040,
#                               'title': 'M 7.1 - 2019 Ridgecrest Earthquake '
#                                        'Sequence',
#                               'tsunami': 1,
#                               'type': 'earthquake',
#                               'types': ',dyfi,finite-fault,focal-mechanism,general-link,general-text,geoserve,ground-failure,impact-link,impact-text,losspager,moment-tensor,nearby-cities,oaf,origin,phase-data,poster,scitech-link,shakemap,',
#                               'tz': -480,
#                               'updated': 1617915742075,
#                               'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ci38457511'},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [129.1692, -6.4078, 212],
#                             'type': 'Point'},
#                'id': 'us600044zz',
#                'properties': {'alert': 'green',
#                               'cdi': 4.1,
#                               'code': '600044zz',
#                               'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us600044zz&format=geojson',
#                               'dmin': 2.629,
#                               'felt': 323,
#                               'gap': 16,
#                               'ids': ',at00ptl1dg,pt19175001,us600044zz,',
#                               'mag': 7.3,
#                               'magType': 'mww',
#                               'mmi': 5.64,
#                               'net': 'us',
#                               'nst': None,
#                               'place': '292km NW of Saumlaki, Indonesia',
#                               'rms': 1.08,
#                               'sig': 952,
#                               'sources': ',at,pt,us,',
#                               'status': 'reviewed',
#                               'time': 1561344819830,
#                               'title': 'M 7.3 - 292km NW of Saumlaki, '
#                                        'Indonesia',
#                               'tsunami': 1,
#                               'type': 'earthquake',
#                               'types': ',dyfi,general-text,geoserve,ground-failure,impact-link,losspager,moment-tensor,origin,phase-data,poster,shakemap,',
#                               'tz': 540,
#                               'updated': 1594402211502,
#                               'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us600044zz'},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [-178.0995, -30.6441, 46],
#                             'type': 'Point'},
#                'id': 'us6000417i',
#                'properties': {'alert': 'green',
#                               'cdi': 8.3,
#                               'code': '6000417i',
#                               'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us6000417i&format=geojson',
#                               'dmin': 1.402,
#                               'felt': 12,
#                               'gap': 11,
#                               'ids': ',at00pt5wzj,us6000417i,pt19166001,',
#                               'mag': 7.3,
#                               'magType': 'mww',
#                               'mmi': 6.465,
#                               'net': 'us',
#                               'nst': None,
#                               'place': "116km NE of L'Esperance Rock, New "
#                                        'Zealand',
#                               'rms': 0.81,
#                               'sig': 830,
#                               'sources': ',at,us,pt,',
#                               'status': 'reviewed',
#                               'time': 1560639304130,
#                               'title': "M 7.3 - 116km NE of L'Esperance Rock, "
#                                        'New Zealand',
#                               'tsunami': 1,
#                               'type': 'earthquake',
#                               'types': ',dyfi,finite-fault,general-text,geoserve,impact-link,impact-text,losspager,moment-tensor,origin,phase-data,poster,shakemap,',
#                               'tz': -720,
#                               'updated': 1567779911040,
#                               'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us6000417i'},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [-75.2697, -5.8119, 122.57],
#                             'type': 'Point'},
#                'id': 'us60003sc0',
#                'properties': {'alert': 'orange',
#                               'cdi': 8.9,
#                               'code': '60003sc0',
#                               'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us60003sc0&format=geojson',
#                               'dmin': 3.18,
#                               'felt': 1788,
#                               'gap': 17,
#                               'ids': ',at00ps3pco,pt19146001,us60003sc0,',
#                               'mag': 8,
#                               'magType': 'mww',
#                               'mmi': 7.945,
#                               'net': 'us',
#                               'nst': None,
#                               'place': '78km SE of Lagunas, Peru',
#                               'rms': 0.84,
#                               'sig': 1890,
#                               'sources': ',at,pt,us,',
#                               'status': 'reviewed',
#                               'time': 1558856475073,
#                               'title': 'M 8.0 - 78km SE of Lagunas, Peru',
#                               'tsunami': 1,
#                               'type': 'earthquake',
#                               'types': ',dyfi,finite-fault,general-text,geoserve,ground-failure,impact-link,impact-text,losspager,moment-tensor,origin,phase-data,poster,shakemap,',
#                               'tz': -300,
#                               'updated': 1614971586497,
#                               'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us60003sc0'},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [152.5967, -4.051, 10],
#                             'type': 'Point'},
#                'id': 'us70003kyy',
#                'properties': {'alert': 'green',
#                               'cdi': 6.9,
#                               'code': '70003kyy',
#                               'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us70003kyy&format=geojson',
#                               'dmin': 0.453,
#                               'felt': 58,
#                               'gap': 16,
#                               'ids': ',pt19134000,us70003kyy,',
#                               'mag': 7.6,
#                               'magType': 'mww',
#                               'mmi': 7.252,
#                               'net': 'us',
#                               'nst': None,
#                               'place': '46km SSE of Namatanai, Papua New '
#                                        'Guinea',
#                               'rms': 1,
#                               'sig': 929,
#                               'sources': ',pt,us,',
#                               'status': 'reviewed',
#                               'time': 1557838705939,
#                               'title': 'M 7.6 - 46km SSE of Namatanai, Papua '
#                                        'New Guinea',
#                               'tsunami': 1,
#                               'type': 'earthquake',
#                               'types': ',dyfi,finite-fault,general-link,general-text,geoserve,ground-failure,impact-link,impact-text,losspager,moment-tensor,origin,phase-data,poster,shakemap,',
#                               'tz': 600,
#                               'updated': 1594162417609,
#                               'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us70003kyy'},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [146.4494, -6.9746, 146],
#                             'type': 'Point'},
#                'id': 'us70003hqb',
#                'properties': {'alert': 'yellow',
#                               'cdi': 6.5,
#                               'code': '70003hqb',
#                               'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us70003hqb&format=geojson',
#                               'dmin': 2.514,
#                               'felt': 77,
#                               'gap': 16,
#                               'ids': ',at00pr3pwp,us70003hqb,pt19126050,',
#                               'mag': 7.1,
#                               'magType': 'mww',
#                               'mmi': 6.159,
#                               'net': 'us',
#                               'nst': None,
#                               'place': '33km NW of Bulolo, Papua New Guinea',
#                               'rms': 1.02,
#                               'sig': 826,
#                               'sources': ',at,us,pt,',
#                               'status': 'reviewed',
#                               'time': 1557177577983,
#                               'title': 'M 7.1 - 33km NW of Bulolo, Papua New '
#                                        'Guinea',
#                               'tsunami': 1,
#                               'type': 'earthquake',
#                               'types': ',dyfi,finite-fault,general-text,geoserve,ground-failure,impact-link,impact-text,losspager,moment-tensor,origin,phase-data,poster,shakemap,',
#                               'tz': 600,
#                               'updated': 1594402818038,
#                               'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us70003hqb'},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [-70.1546, -14.7131, 267],
#                             'type': 'Point'},
#                'id': 'us1000j96d',
#                'properties': {'alert': 'green',
#                               'cdi': 7.2,
#                               'code': '1000j96d',
#                               'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us1000j96d&format=geojson',
#                               'dmin': 2.501,
#                               'felt': 164,
#                               'gap': 42,
#                               'ids': ',at00pnoj8k,pt19060000,us1000j96d,',
#                               'mag': 7,
#                               'magType': 'mww',
#                               'mmi': 4.423,
#                               'net': 'us',
#                               'nst': None,
#                               'place': '23km NNE of Azangaro, Peru',
#                               'rms': 1.13,
#                               'sig': 872,
#                               'sources': ',at,pt,us,',
#                               'status': 'reviewed',
#                               'time': 1551430242591,
#                               'title': 'M 7.0 - 23km NNE of Azangaro, Peru',
#                               'tsunami': 1,
#                               'type': 'earthquake',
#                               'types': ',dyfi,finite-fault,general-text,geoserve,ground-failure,impact-link,impact-text,losspager,moment-tensor,origin,phase-data,poster,shakemap,',
#                               'tz': -300,
#                               'updated': 1617761985001,
#                               'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us1000j96d'},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [-77.0505, -2.1862, 145],
#                             'type': 'Point'},
#                'id': 'us2000jlfv',
#                'properties': {'alert': 'yellow',
#                               'cdi': 6.7,
#                               'code': '2000jlfv',
#                               'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us2000jlfv&format=geojson',
#                               'dmin': 2.045,
#                               'felt': 418,
#                               'gap': 15,
#                               'ids': ',at00pnbol0,pt19053000,us2000jlfv,',
#                               'mag': 7.5,
#                               'magType': 'mww',
#                               'mmi': 7.281,
#                               'net': 'us',
#                               'nst': None,
#                               'place': '111km ESE of Palora, Ecuador',
#                               'rms': 1.12,
#                               'sig': 1145,
#                               'sources': ',at,pt,us,',
#                               'status': 'reviewed',
#                               'time': 1550830643770,
#                               'title': 'M 7.5 - 111km ESE of Palora, Ecuador',
#                               'tsunami': 1,
#                               'type': 'earthquake',
#                               'types': ',dyfi,finite-fault,general-text,geoserve,ground-failure,impact-link,impact-text,losspager,moment-tensor,origin,phase-data,poster,shakemap,',
#                               'tz': -300,
#                               'updated': 1594162356277,
#                               'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us2000jlfv'},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [126.9209, 5.8983, 60.21],
#                             'type': 'Point'},
#                'id': 'us2000iyta',
#                'properties': {'alert': 'green',
#                               'cdi': 5.2,
#                               'code': '2000iyta',
#                               'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us2000iyta&format=geojson',
#                               'dmin': 1.769,
#                               'felt': 128,
#                               'gap': 21,
#                               'ids': ',at00pkhbhc,pt18363000,us2000iyta,',
#                               'mag': 7,
#                               'magType': 'mww',
#                               'mmi': 5.22,
#                               'net': 'us',
#                               'nst': None,
#                               'place': '96km ESE of Pondaguitan, Philippines',
#                               'rms': 1.45,
#                               'sig': 820,
#                               'sources': ',at,pt,us,',
#                               'status': 'reviewed',
#                               'time': 1546054749740,
#                               'title': 'M 7.0 - 96km ESE of Pondaguitan, '
#                                        'Philippines',
#                               'tsunami': 1,
# ...
#                               'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=usp0009xzy&format=geojson',
#                               'dmin': None,
#                               'felt': None,
#                               'gap': None,
#                               'ids': ',choy20000806072712,gcmtc080600b,usp0009xzy,gcmt20000806072712,duputel080600b,iscgem1738788,',
#                               'mag': 7.4,
#                               'magType': 'mwc',
#                               'mmi': None,
#                               'net': 'us',
#                               'nst': 588,
#                               'place': 'Bonin Islands, Japan region',
#                               'rms': 0.9,
#                               'sig': 842,
#                               'sources': ',choy,gcmt,us,gcmt,duputel,iscgem,',
#                               'status': 'reviewed',
#                               'time': 965546832900,
#                               'title': 'M 7.4 - Bonin Islands, Japan region',
#                               'tsunami': 0,
#                               'type': 'earthquake',
#                               'types': ',focal-mechanism,general-text,impact-text,moment-tensor,origin,phase-data,',
#                               'tz': None,
#                               'updated': 1510071863950,
#                               'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/usp0009xzy'},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [97.453, -13.802, 10],
#                             'type': 'Point'},
#                'id': 'usp0009ut0',
#                'properties': {'alert': None,
#                               'cdi': None,
#                               'code': 'p0009ut0',
#                               'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=usp0009ut0&format=geojson',
#                               'dmin': None,
#                               'felt': None,
#                               'gap': None,
#                               'ids': ',usp0009ut0,choy20000618144413,gcmtc061800a,gcmt20000618144413,duputel061800a,iscgem1736624,',
#                               'mag': 7.9,
#                               'magType': 'mwc',
#                               'mmi': 4.809,
#                               'net': 'us',
#                               'nst': 405,
#                               'place': 'South Indian Ocean',
#                               'rms': 1.16,
#                               'sig': 960,
#                               'sources': ',us,choy,gcmt,gcmt,duputel,iscgem,',
#                               'status': 'reviewed',
#                               'time': 961339453310,
#                               'title': 'M 7.9 - South Indian Ocean',
#                               'tsunami': 0,
#                               'type': 'earthquake',
#                               'types': ',finite-fault,focal-mechanism,general-text,impact-text,moment-tensor,origin,phase-data,shakemap,',
#                               'tz': None,
#                               'updated': 1600205245430,
#                               'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/usp0009ut0'},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [102.087, -4.721, 33],
#                             'type': 'Point'},
#                'id': 'usp0009txv',
#                'properties': {'alert': None,
#                               'cdi': None,
#                               'code': 'p0009txv',
#                               'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=usp0009txv&format=geojson',
#                               'dmin': None,
#                               'felt': None,
#                               'gap': None,
#                               'ids': ',usp0009txv,choy20000604162826,gcmtm060400d,gcmt20000604162826,duputel060400d,atlas20000604162827,iscgem1736014,',
#                               'mag': 7.9,
#                               'magType': 'mwc',
#                               'mmi': 7.885,
#                               'net': 'us',
#                               'nst': 379,
#                               'place': 'southern Sumatra, Indonesia',
#                               'rms': 1.1,
#                               'sig': 960,
#                               'sources': ',us,choy,gcmt,gcmt,duputel,atlas,iscgem,',
#                               'status': 'reviewed',
#                               'time': 960136106170,
#                               'title': 'M 7.9 - southern Sumatra, Indonesia',
#                               'tsunami': 0,
#                               'type': 'earthquake',
#                               'types': ',finite-fault,focal-mechanism,general-text,impact-text,moment-tensor,origin,phase-data,shakemap,trump-shakemap,',
#                               'tz': None,
#                               'updated': 1594169755616,
#                               'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/usp0009txv'},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [-66.452, -23.548, 225],
#                             'type': 'Point'},
#                'id': 'usp0009suu',
#                'properties': {'alert': None,
#                               'cdi': None,
#                               'code': 'p0009suu',
#                               'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=usp0009suu&format=geojson',
#                               'dmin': None,
#                               'felt': None,
#                               'gap': None,
#                               'ids': ',choy20000512184318,usp0009suu,gcmt20000512184318,duputel051200c,atlas20000512184319,iscgem1837083,',
#                               'mag': 7.2,
#                               'magType': 'mwc',
#                               'mmi': 5.178,
#                               'net': 'us',
#                               'nst': None,
#                               'place': 'Jujuy, Argentina',
#                               'rms': 0.86,
#                               'sig': 798,
#                               'sources': ',choy,us,gcmt,duputel,atlas,iscgem,',
#                               'status': 'reviewed',
#                               'time': 958156998120,
#                               'title': 'M 7.2 - Jujuy, Argentina',
#                               'tsunami': 0,
#                               'type': 'earthquake',
#                               'types': ',focal-mechanism,general-text,impact-text,moment-tensor,origin,phase-data,shakemap,',
#                               'tz': None,
#                               'updated': 1600204940596,
#                               'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/usp0009suu'},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [123.573, -1.105, 26],
#                             'type': 'Point'},
#                'id': 'usp0009sbh',
#                'properties': {'alert': None,
#                               'cdi': None,
#                               'code': 'p0009sbh',
#                               'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=usp0009sbh&format=geojson',
#                               'dmin': None,
#                               'felt': None,
#                               'gap': None,
#                               'ids': ',usp0009sbh,choy20000504042116,gcmtc050400a,gcmt20000504042116,duputel050400a,atlas20000504042117,iscgem1836975,',
#                               'mag': 7.6,
#                               'magType': 'mwc',
#                               'mmi': 6.715,
#                               'net': 'us',
#                               'nst': None,
#                               'place': 'Sulawesi, Indonesia',
#                               'rms': 1.14,
#                               'sig': 889,
#                               'sources': ',us,choy,gcmt,gcmt,duputel,atlas,iscgem,',
#                               'status': 'reviewed',
#                               'time': 957414076210,
#                               'title': 'M 7.6 - Sulawesi, Indonesia',
#                               'tsunami': 0,
#                               'type': 'earthquake',
#                               'types': ',finite-fault,focal-mechanism,general-text,impact-text,moment-tensor,origin,phase-data,shakemap,trump-shakemap,',
#                               'tz': None,
#                               'updated': 1600204885142,
#                               'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/usp0009sbh'},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [-62.99, -28.307, 608.5],
#                             'type': 'Point'},
#                'id': 'usp0009rrc',
#                'properties': {'alert': None,
#                               'cdi': None,
#                               'code': 'p0009rrc',
#                               'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=usp0009rrc&format=geojson',
#                               'dmin': None,
#                               'felt': None,
#                               'gap': None,
#                               'ids': ',choy20000423092723,gcmtc042300b,usp0009rrc,gcmt20000423092723,duputel042300b,iscgem2208257,',
#                               'mag': 7,
#                               'magType': 'mwb',
#                               'mmi': None,
#                               'net': 'us',
#                               'nst': None,
#                               'place': 'Santiago Del Estero, Argentina',
#                               'rms': 0.89,
#                               'sig': 754,
#                               'sources': ',choy,gcmt,us,gcmt,duputel,iscgem,',
#                               'status': 'reviewed',
#                               'time': 956482043320,
#                               'title': 'M 7.0 - Santiago Del Estero, Argentina',
#                               'tsunami': 0,
#                               'type': 'earthquake',
#                               'types': ',focal-mechanism,general-text,impact-text,moment-tensor,origin,phase-data,',
#                               'tz': None,
#                               'updated': 1510071257222,
#                               'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/usp0009rrc'},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [143.73, 22.338, 126.5],
#                             'type': 'Point'},
#                'id': 'usp0009qb4',
#                'properties': {'alert': None,
#                               'cdi': None,
#                               'code': 'p0009qb4',
#                               'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=usp0009qb4&format=geojson',
#                               'dmin': None,
#                               'felt': None,
#                               'gap': None,
#                               'ids': ',usp0009qb4,choy20000328110022,gcmtm032800c,gcmt20000328110022,duputel032800c,iscgem1733948,',
#                               'mag': 7.6,
#                               'magType': 'mwc',
#                               'mmi': None,
#                               'net': 'us',
#                               'nst': None,
#                               'place': 'Volcano Islands, Japan region',
#                               'rms': 1.22,
#                               'sig': 889,
#                               'sources': ',us,choy,gcmt,gcmt,duputel,iscgem,',
#                               'status': 'reviewed',
#                               'time': 954241222510,
#                               'title': 'M 7.6 - Volcano Islands, Japan region',
#                               'tsunami': 0,
#                               'type': 'earthquake',
#                               'types': ',finite-fault,focal-mechanism,general-text,impact-text,moment-tensor,origin,phase-data,',
#                               'tz': None,
#                               'updated': 1539805077922,
#                               'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/usp0009qb4'},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [173.818, -19.528, 33],
#                             'type': 'Point'},
#                'id': 'usp0009nxg',
#                'properties': {'alert': None,
#                               'cdi': None,
#                               'code': 'p0009nxg',
#                               'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=usp0009nxg&format=geojson',
#                               'dmin': None,
#                               'felt': None,
#                               'gap': None,
#                               'ids': ',choy20000225014358,gcmtc022500b,usp0009nxg,gcmt20000225014358,duputel022500b,iscgem1733126,',
#                               'mag': 7.1,
#                               'magType': 'mwc',
#                               'mmi': None,
#                               'net': 'us',
#                               'nst': None,
#                               'place': 'Vanuatu region',
#                               'rms': 1.2,
#                               'sig': 776,
#                               'sources': ',choy,gcmt,us,gcmt,duputel,iscgem,',
#                               'status': 'reviewed',
#                               'time': 951443038640,
#                               'title': 'M 7.1 - Vanuatu region',
#                               'tsunami': 0,
#                               'type': 'earthquake',
#                               'types': ',focal-mechanism,general-text,moment-tensor,origin,phase-data,',
#                               'tz': None,
#                               'updated': 1510071450218,
#                               'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/usp0009nxg'},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [-174.248, -16.925, 183.4],
#                             'type': 'Point'},
#                'id': 'usp0009kx3',
#                'properties': {'alert': None,
#                               'cdi': None,
#                               'code': 'p0009kx3',
#                               'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=usp0009kx3&format=geojson',
#                               'dmin': None,
#                               'felt': None,
#                               'gap': None,
#                               'ids': ',choy20000108164720,gcmtc010800g,usp0009kx3,gcmt20000108164720,duputel010800g,iscgem2348979,atlas20000108164718,',
#                               'mag': 7.2,
#                               'magType': 'mwc',
#                               'mmi': 5.8,
#                               'net': 'us',
#                               'nst': None,
#                               'place': 'Tonga',
#                               'rms': 1.25,
#                               'sig': 798,
#                               'sources': ',choy,gcmt,us,gcmt,duputel,iscgem,atlas,',
#                               'status': 'reviewed',
#                               'time': 947350040580,
#                               'title': 'M 7.2 - Tonga',
#                               'tsunami': 0,
#                               'type': 'earthquake',
#                               'types': ',focal-mechanism,general-text,impact-text,moment-tensor,origin,phase-data,shakemap,',
#                               'tz': None,
#                               'updated': 1587060843176,
#                               'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/usp0009kx3'},
#                'type': 'Feature'}],
#  'metadata': {'api': '1.10.3',
#               'count': 320,
#               'generated': 1618375440000,
#               'status': 200,
#               'title': 'USGS Earthquakes',
#               'url': 'https://earthquake.usgs.gov/fdsnws/event/1/query?format=geojson&starttime=2000-01-01&minmagnitude=7'},
#  'type': 'FeatureCollection'}

# %%
# List out desired fields that will make up Dataframe
time = []
longitude = []
latitude = []
alert = []
depth = []
magnitude = []
tsunami = []
place = []
type = []
# Out:
#                 type                                           features  \
# 0  FeatureCollection  [{'type': 'Feature', 'properties': {'mag': 7, ...
#
#                                                 bbox  metadata.generated  \
# 0  [-179.575, -61.029, 4.2, 179.3587, 63.5141, 67...       1618375440000
#
#                                         metadata.url    metadata.title  \
# 0  https://earthquake.usgs.gov/fdsnws/event/1/que...  USGS Earthquakes
#
#    metadata.status metadata.api  metadata.count
# 0              200       1.10.3             320
